# %%
import pandas as pd
import numpy as np
import cPickle as pickle
import math

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# # Se carga el set de entrenamiento

# %%
prop = pickle.load(open("../../datos/Data.p","rb"))

# %%
#OJO CON ESTO
proper = pickle.load(open("../../datos/propiedadesPruebaConColTransGas.p", "rb"))
#agrego el set de pruebas con los datos posta al de entrenamiento
propTOT = pd.merge(proper, prop, how="outer")

# %%
propTOT
# Out:
#                                              id  created_on property_type  \
# 0                                   2.31650e+06  2017-08-23          casa
# 1                                   2.32088e+06  2017-08-24          casa
# 2                                   2.32174e+06  2017-08-25  departamento
# 3                                    2.2768e+06  2017-08-08          casa
# 4                                   2.33036e+06  2017-08-28          casa
# 5                                   2.30973e+06  2017-08-18  departamento
# 6                                   2.31474e+06  2017-08-22  departamento
# 7                                   2.27202e+06  2017-08-03          casa
# 8                                   2.26526e+06  2017-08-01  departamento
# 9                                   2.31286e+06  2017-08-20  departamento
# 10                                  2.28423e+06  2017-08-09  departamento
# 11                                  2.32289e+06  2017-08-25  departamento
# 12                                  2.27422e+06  2017-08-05  departamento
# 13                                  2.28431e+06  2017-08-09  departamento
# 14                                  2.27202e+06  2017-08-03          casa
# 15                                  2.24295e+06  2017-08-15          casa
# 16                                  2.33139e+06  2017-08-29          casa
# 17                                   2.2814e+06  2017-08-09          casa
# 18                                  2.28974e+06  2017-08-11  departamento
# 19                                  2.27998e+06  2017-08-09          casa
# 20                                  2.28138e+06  2017-08-09  departamento
# 21                                  2.27292e+06  2017-08-05  departamento
# 22                                  2.28301e+06  2017-08-09          casa
# 23                                  2.29815e+06  2017-08-15  departamento
# 24                                  2.28445e+06  2017-08-09          casa
# 25                                  2.28003e+06  2017-08-09          casa
# 26                                  2.28137e+06  2017-08-09          casa
# 27                                  2.28345e+06  2017-08-09          casa
# 28                                  2.28345e+06  2017-08-09          casa
# 29                                  2.28332e+06  2017-08-09  departamento
# ...                                         ...         ...           ...
# 86610  eee089f4d7ee6884fec59ff56fa08ec3c6a7f62c  2017-08-01     apartment
# 86611  69746a0e825b24661327fb16a6e9c9b1f94447e2  2017-08-01     apartment
# 86612  b2e3f9b2a03d94f938b78e8cb4319e01edc84900  2017-08-01         house
# 86613  ef57596c881b0b3167aecbe263d88c5a2a280f61  2017-08-01     apartment
# 86614  3f7e9d598124fdaa20721e5f60e38d94fc697d7e  2017-08-01     apartment
# 86615  2c77c74e5129a9311c506118e0995cd47b8e7010  2017-08-01     apartment
# 86616  2d00e9db4128163c7224e34c2805efb8d1227181  2017-08-01     apartment
# 86617  7a6f5d348841343364b4eca25cff3fe517078307  2017-08-01         store
# 86618  476ef698dde766c8cd373471cd2fd20072ec3e91  2017-08-01     apartment
# 86619  f77dde7747938e2ee5503ec565d4b5899cbe6f24  2017-08-01     apartment
# 86620  615970717b6cc0bc04be708389f7150626d882e7  2017-08-01     apartment
# 86621  7e36c314d7539d731d21fe4b2fbce2579c82d186  2017-08-01     apartment
# 86622  cbe3d5bf876b75c1e19e92a64b55db298814f35d  2017-08-01     apartment
# 86623  88be647323a048279abf9219c99f2a12135ea5bd  2017-08-01     apartment
# 86624  59efda89d9e358a4bf7d0cea1102e3093f231961  2017-08-01     apartment
# 86625  7d650a97a2b38c75555dc35c9af21e7d96e709f9  2017-08-01     apartment
# 86626  d1d4c50b133117e6091fb2a3426baf183a76252e  2017-08-01     apartment
# 86627  e6687b86bf447d1952756561f807c13ab7e46745  2017-08-01     apartment
# 86628  841c8b29796e7cef63d6573cae25e57c65717f2f  2017-08-01     apartment
# 86629  1e50ea0c4cf3ad492ae78cec01630088ae689b03  2017-08-01     apartment
# 86630  2db3904ff7a0e0381b11aabb1d2738b2b01476c9  2017-08-01     apartment
# 86631  621a3ba6a67dd72a7e7e5b692cc1f4434e4bdf56  2017-08-01     apartment
# 86632  778268d474f1147253362607acf0b72ebfc5bd63  2017-08-01         house
# 86633  8db5a894e83b44233d77a2894e95e448ea4374d1  2017-08-01     apartment
# 86634  7e57cce1a2b635205d5571424c7100fa3536f311  2017-08-01     apartment
# 86635  fab80d207cd3bcf4092627473845f35396670c80  2017-08-01     apartment
# 86636  38923090847e746add1e7cbdefd03128a2b358da  2017-08-01         house
# 86637  a1de3c3be7e6381dffb267240e123de8c324100b  2017-08-01     apartment
# 86638  6b119cac3825c981da11b037e41b0014096a3bed  2017-08-01     apartment
# 86639  aba0d7d6f6f87365d97a4f7bc133f3ef59a70a20  2017-08-01         house
#
#       operation            place_name  \
# 0         venta              La Plata
# 1         venta               Liniers
# 2         venta         Villa Urquiza
# 3         venta       Tres de Febrero
# 4         venta       Tres de Febrero
# 5         venta         Pablo Podestá
# 6         venta              Belgrano
# 7         venta           Santa Juana
# 8         venta            Villa Luro
# 9         venta              Belgrano
# 10        venta                Moreno
# 11        venta       Lomas de Zamora
# 12        venta       Lomas de Zamora
# 13        venta                 Morón
# 14        venta  Country Saint Thomas
# 15        venta               La Reja
# 16        venta               La Reja
# 17        venta             Domselaar
# 18        venta                Abasto
# 19        venta               El Pato
# 20        venta            Don Orione
# 21        venta              Recoleta
# 22        venta              Guernica
# 23        venta       Valentín Alsina
# 24        venta                Moreno
# 25        venta          Paso del Rey
# 26        venta           San Vicente
# 27        venta     Francisco Alvarez
# 28        venta          Paso del Rey
# 29        venta                Moreno
# ...         ...                   ...
# 86610      sell              Belgrano
# 86611      sell              Belgrano
# 86612      sell                Beccar
# 86613      sell         Villa Urquiza
# 86614      sell       Capital Federal
# 86615      sell             Caballito
# 86616      sell              Recoleta
# 86617      sell       Capital Federal
# 86618      sell                Olivos
# 86619      sell              Belgrano
# 86620      sell       Capital Federal
# 86621      sell       Capital Federal
# 86622      sell       Capital Federal
# 86623      sell       Capital Federal
# 86624      sell       Capital Federal
# 86625      sell       Capital Federal
# 86626      sell                 Nuñez
# 86627      sell                Olivos
# 86628      sell               Coghlan
# 86629      sell                Olivos
# 86630      sell             Caballito
# 86631      sell          Barrio Norte
# 86632      sell            El Palomar
# 86633      sell              Recoleta
# 86634      sell              Recoleta
# 86635      sell               Palermo
# 86636      sell                Matheu
# 86637      sell          Barrio Norte
# 86638      sell         Villa Urquiza
# 86639      sell              Belgrano
#
#                                  place_with_parent_names country_name  \
# 0            |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 1                    |Argentina|Capital Federal|Liniers|    Argentina
# 2              |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 3      |Argentina|Bs.As. G.B.A. Zona Oeste|Tres de Fe...    Argentina
# 4      |Argentina|Bs.As. G.B.A. Zona Oeste|Tres de Fe...    Argentina
# 5      |Argentina|Bs.As. G.B.A. Zona Oeste|Tres de Fe...    Argentina
# 6                   |Argentina|Capital Federal|Belgrano|    Argentina
# 7      |Argentina|Bs.As. G.B.A. Zona Sur|Esteban Eche...    Argentina
# 8                 |Argentina|Capital Federal|Villa Luro|    Argentina
# 9                   |Argentina|Capital Federal|Belgrano|    Argentina
# 10     |Argentina|Bs.As. G.B.A. Zona Oeste|Moreno|Mor...    Argentina
# 11     |Argentina|Bs.As. G.B.A. Zona Sur|Lomas de Zam...    Argentina
# 12     |Argentina|Bs.As. G.B.A. Zona Sur|Lomas de Zam...    Argentina
# 13      |Argentina|Bs.As. G.B.A. Zona Oeste|Morón|Morón|    Argentina
# 14     |Argentina|Bs.As. G.B.A. Zona Sur|Esteban Eche...    Argentina
# 15     |Argentina|Bs.As. G.B.A. Zona Oeste|Moreno|La ...    Argentina
# 16     |Argentina|Bs.As. G.B.A. Zona Oeste|Moreno|La ...    Argentina
# 17     |Argentina|Bs.As. G.B.A. Zona Sur|San Vicente|...    Argentina
# 18                    |Argentina|Capital Federal|Abasto|    Argentina
# 19     |Argentina|Bs.As. G.B.A. Zona Sur|Berazategui|...    Argentina
# 20     |Argentina|Bs.As. G.B.A. Zona Sur|Almirante Br...    Argentina
# 21                  |Argentina|Capital Federal|Recoleta|    Argentina
# 22     |Argentina|Bs.As. G.B.A. Zona Sur|Presidente P...    Argentina
# 23     |Argentina|Bs.As. G.B.A. Zona Sur|Lanús|Valent...    Argentina
# 24     |Argentina|Bs.As. G.B.A. Zona Oeste|Moreno|Mor...    Argentina
# 25     |Argentina|Bs.As. G.B.A. Zona Oeste|Moreno|Pas...    Argentina
# 26     |Argentina|Bs.As. G.B.A. Zona Sur|San Vicente|...    Argentina
# 27     |Argentina|Bs.As. G.B.A. Zona Oeste|Moreno|Fra...    Argentina
# 28     |Argentina|Bs.As. G.B.A. Zona Oeste|Moreno|Pas...    Argentina
# 29     |Argentina|Bs.As. G.B.A. Zona Oeste|Moreno|Mor...    Argentina
# ...                                                  ...          ...
# 86610               |Argentina|Capital Federal|Belgrano|    Argentina
# 86611               |Argentina|Capital Federal|Belgrano|    Argentina
# 86612  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 86613          |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 86614                        |Argentina|Capital Federal|    Argentina
# 86615              |Argentina|Capital Federal|Caballito|    Argentina
# 86616               |Argentina|Capital Federal|Recoleta|    Argentina
# 86617                        |Argentina|Capital Federal|    Argentina
# 86618  |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 86619               |Argentina|Capital Federal|Belgrano|    Argentina
# 86620                        |Argentina|Capital Federal|    Argentina
# 86621                        |Argentina|Capital Federal|    Argentina
# 86622                        |Argentina|Capital Federal|    Argentina
# 86623                        |Argentina|Capital Federal|    Argentina
# 86624                        |Argentina|Capital Federal|    Argentina
# 86625                        |Argentina|Capital Federal|    Argentina
# 86626                  |Argentina|Capital Federal|Nuñez|    Argentina
# 86627  |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 86628                |Argentina|Capital Federal|Coghlan|    Argentina
# 86629  |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 86630              |Argentina|Capital Federal|Caballito|    Argentina
# 86631           |Argentina|Capital Federal|Barrio Norte|    Argentina
# 86632  |Argentina|Bs.As. G.B.A. Zona Oeste|Morón|El P...    Argentina
# 86633               |Argentina|Capital Federal|Recoleta|    Argentina
# 86634               |Argentina|Capital Federal|Recoleta|    Argentina
# 86635                |Argentina|Capital Federal|Palermo|    Argentina
# 86636  |Argentina|Bs.As. G.B.A. Zona Norte|Escobar|Ma...    Argentina
# 86637           |Argentina|Capital Federal|Barrio Norte|    Argentina
# 86638          |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 86639               |Argentina|Capital Federal|Belgrano|    Argentina
#
#                      state_name                        lat-lon        lat  \
# 0        Bs.As. G.B.A. Zona Sur                            NaN        NaN
# 1               Capital Federal        -34.6458753,-58.5174427 -34.645875
# 2               Capital Federal        -34.5645218,-58.4869765 -34.564522
# 3      Bs.As. G.B.A. Zona Oeste         -34.583011,-58.5959924 -34.583011
# 4      Bs.As. G.B.A. Zona Oeste        -34.5800375,-58.5927217 -34.580038
# 5      Bs.As. G.B.A. Zona Oeste        -34.5757443,-58.6040724 -34.575744
# 6               Capital Federal                            NaN        NaN
# 7        Bs.As. G.B.A. Zona Sur        -34.8994132,-58.4883038 -34.899413
# 8               Capital Federal        -34.6393657,-58.5056071 -34.639366
# 9               Capital Federal        -34.5628239,-58.4436145 -34.562824
# 10     Bs.As. G.B.A. Zona Oeste      -34.63207626,-58.79127502 -34.632076
# 11       Bs.As. G.B.A. Zona Sur        -34.7602034,-58.4507948 -34.760203
# 12       Bs.As. G.B.A. Zona Sur         -34.763324,-58.3988587 -34.763324
# 13     Bs.As. G.B.A. Zona Oeste         -34.643183,-58.6196315 -34.643183
# 14       Bs.As. G.B.A. Zona Sur        -34.8880732,-58.4998722 -34.888073
# 15     Bs.As. G.B.A. Zona Oeste                            NaN        NaN
# 16     Bs.As. G.B.A. Zona Oeste                            NaN        NaN
# 17       Bs.As. G.B.A. Zona Sur      -35.06520081,-58.27929306 -35.065201
# 18              Capital Federal          -34.602874,-58.410708 -34.602874
# 19       Bs.As. G.B.A. Zona Sur      -34.83102417,-58.17598343 -34.831024
# 20       Bs.As. G.B.A. Zona Sur      -34.81479263,-58.33547211 -34.814793
# 21              Capital Federal                            NaN        NaN
# 22       Bs.As. G.B.A. Zona Sur      -34.91795349,-58.38069534 -34.917953
# 23       Bs.As. G.B.A. Zona Sur   -34.6790563954,-58.425418823 -34.679056
# 24     Bs.As. G.B.A. Zona Oeste      -34.63503265,-58.81325912 -34.635033
# 25     Bs.As. G.B.A. Zona Oeste      -34.64294434,-58.75792694 -34.642944
# 26       Bs.As. G.B.A. Zona Sur      -35.03785324,-58.41334915 -35.037853
# 27     Bs.As. G.B.A. Zona Oeste       -34.6173439,-58.87833786 -34.617344
# 28     Bs.As. G.B.A. Zona Oeste      -34.64301682,-58.76659012 -34.643017
# 29     Bs.As. G.B.A. Zona Oeste      -34.60911942,-58.81493759 -34.609119
# ...                         ...                            ...        ...
# 86610           Capital Federal   -34.563685346,-58.4426825896 -34.563685
# 86611           Capital Federal                            NaN        NaN
# 86612  Bs.As. G.B.A. Zona Norte                            NaN        NaN
# 86613           Capital Federal  -34.5706388726,-58.4755963355 -34.570639
# 86614           Capital Federal                            NaN        NaN
# 86615           Capital Federal                            NaN        NaN
# 86616           Capital Federal  -34.5910018358,-58.3949034653 -34.591002
# 86617           Capital Federal   -34.609536555,-58.4642484381 -34.609537
# 86618  Bs.As. G.B.A. Zona Norte                            NaN        NaN
# 86619           Capital Federal                            NaN        NaN
# 86620           Capital Federal                            NaN        NaN
# 86621           Capital Federal                            NaN        NaN
# 86622           Capital Federal                            NaN        NaN
# 86623           Capital Federal                            NaN        NaN
# 86624           Capital Federal                            NaN        NaN
# 86625           Capital Federal                            NaN        NaN
# 86626           Capital Federal                            NaN        NaN
# 86627  Bs.As. G.B.A. Zona Norte                            NaN        NaN
# 86628           Capital Federal                            NaN        NaN
# 86629  Bs.As. G.B.A. Zona Norte                            NaN        NaN
# 86630           Capital Federal                            NaN        NaN
# 86631           Capital Federal                            NaN        NaN
# 86632  Bs.As. G.B.A. Zona Oeste                            NaN        NaN
# 86633           Capital Federal                            NaN        NaN
# 86634           Capital Federal                            NaN        NaN
# 86635           Capital Federal  -34.5745642487,-58.4413345724 -34.574564
# 86636  Bs.As. G.B.A. Zona Norte                            NaN        NaN
# 86637           Capital Federal  -34.5837423312,-58.3999128406 -34.583742
# 86638           Capital Federal                            NaN        NaN
# 86639           Capital Federal  -34.5744697838,-58.4394831816 -34.574470
#
#         ...       price  currency  price_aprox_local_currency  \
# 0       ...         NaN       NaN                         NaN
# 1       ...         NaN       NaN                         NaN
# 2       ...         NaN       NaN                         NaN
# 3       ...         NaN       NaN                         NaN
# 4       ...         NaN       NaN                         NaN
# 5       ...         NaN       NaN                         NaN
# 6       ...         NaN       NaN                         NaN
# 7       ...         NaN       NaN                         NaN
# 8       ...         NaN       NaN                         NaN
# 9       ...         NaN       NaN                         NaN
# 10      ...         NaN       NaN                         NaN
# 11      ...         NaN       NaN                         NaN
# 12      ...         NaN       NaN                         NaN
# 13      ...         NaN       NaN                         NaN
# 14      ...         NaN       NaN                         NaN
# 15      ...         NaN       NaN                         NaN
# 16      ...         NaN       NaN                         NaN
# 17      ...         NaN       NaN                         NaN
# 18      ...         NaN       NaN                         NaN
# 19      ...         NaN       NaN                         NaN
# 20      ...         NaN       NaN                         NaN
# 21      ...         NaN       NaN                         NaN
# 22      ...         NaN       NaN                         NaN
# 23      ...         NaN       NaN                         NaN
# 24      ...         NaN       NaN                         NaN
# 25      ...         NaN       NaN                         NaN
# 26      ...         NaN       NaN                         NaN
# 27      ...         NaN       NaN                         NaN
# 28      ...         NaN       NaN                         NaN
# 29      ...         NaN       NaN                         NaN
# ...     ...         ...       ...                         ...
# 86610   ...    410000.0       USD                  7234245.00
# 86611   ...    870000.0       USD                 15350715.00
# 86612   ...    498000.0       USD                  8786961.00
# 86613   ...    131500.0       USD                  2320251.75
# 86614   ...    129000.0       USD                  2276140.50
# 86615   ...    205000.0       USD                  3617122.50
# 86616   ...    220000.0       USD                  3881790.00
# 86617   ...     60000.0       USD                  1058670.00
# 86618   ...    452100.0       USD                  7977078.45
# 86619   ...    490000.0       USD                  8645805.00
# 86620   ...    144000.0       USD                  2540808.00
# 86621   ...    141000.0       USD                  2487874.50
# 86622   ...    138800.0       USD                  2449056.60
# 86623   ...    133000.0       USD                  2346718.50
# 86624   ...    135000.0       USD                  2382007.50
# 86625   ...    137000.0       USD                  2417296.50
# 86626   ...    380000.0       USD                  6704910.00
# 86627   ...    548200.0       USD                  9672714.90
# 86628   ...    219000.0       USD                  3864145.50
# 86629   ...    652200.0       USD                 11507742.90
# 86630   ...    330000.0       USD                  5822685.00
# 86631   ...    245000.0       USD                  4322902.50
# 86632   ...    120000.0       USD                  2117340.00
# 86633   ...    142000.0       USD                  2505519.00
# 86634   ...    215000.0       USD                  3793567.50
# 86635   ...    145000.0       USD                  2558452.50
# 86636   ...    118000.0       USD                  2082051.00
# 86637   ...    155000.0       USD                  2734897.50
# 86638   ...    219000.0       USD                  3864145.50
# 86639   ...    108000.0       USD                  1905606.00
#
#                                            properati_url  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 86610  http://www.properati.com.ar/1cj7c_venta_depart...
# 86611  http://www.properati.com.ar/1cja2_venta_depart...
# 86612  http://www.properati.com.ar/1cja6_venta_casa_b...
# 86613  http://www.properati.com.ar/1cja7_venta_depart...
# 86614  http://www.properati.com.ar/1cjaa_venta_depart...
# 86615  http://www.properati.com.ar/1cjba_venta_depart...
# 86616  http://www.properati.com.ar/1cjbb_venta_depart...
# 86617  http://www.properati.com.ar/1cjbw_venta_local_...
# 86618  http://www.properati.com.ar/1cjd6_venta_depart...
# 86619  http://www.properati.com.ar/1cjd9_venta_depart...
# 86620  http://www.properati.com.ar/1cjdi_venta_depart...
# 86621  http://www.properati.com.ar/1cjdk_venta_depart...
# 86622  http://www.properati.com.ar/1cjdn_venta_depart...
# 86623  http://www.properati.com.ar/1cjdo_venta_depart...
# 86624  http://www.properati.com.ar/1cjdr_venta_depart...
# 86625  http://www.properati.com.ar/1cjdu_venta_depart...
# 86626  http://www.properati.com.ar/1cjdv_venta_depart...
# 86627  http://www.properati.com.ar/1cjdz_venta_depart...
# 86628  http://www.properati.com.ar/1cje3_venta_depart...
# 86629  http://www.properati.com.ar/1cje4_venta_depart...
# 86630  http://www.properati.com.ar/1cje7_venta_depart...
# 86631  http://www.properati.com.ar/1cjel_venta_depart...
# 86632  http://www.properati.com.ar/1cjfy_venta_casa_e...
# 86633  http://www.properati.com.ar/1cjg4_venta_depart...
# 86634  http://www.properati.com.ar/1cjg5_venta_depart...
# 86635  http://www.properati.com.ar/1cjg7_venta_depart...
# 86636  http://www.properati.com.ar/1cjg8_venta_casa_m...
# 86637  http://www.properati.com.ar/1cjga_venta_depart...
# 86638  http://www.properati.com.ar/1cjgb_venta_depart...
# 86639  http://www.properati.com.ar/1cjge_venta_casa_b...
#
#                                                    title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 86610  Av .Luis Maria Campos 1400- Belgrano-Capital F...
# 86611         Torre Forum Alcorta- Impecable 3 ambientes
# 86612  Ruca Inmuebles | Venta | Lomas de San Isidro |...
# 86613  VENTA DEPARTAMENTO AMBIENTE DIVISIBLE A ESTREN...
# 86614         Departamento apto profesional en el Centro
# 86615                           Departamento - Caballito
# 86616  Departamento 2 ambientes en Venta-Edificio con...
# 86617                          Local - Villa Gral. Mitre
# 86618                  Duplex de 3 amb - Olivos-Vias/Rio
# 86619                            Departamento - Belgrano
# 86620                        Departamento - P.Avellaneda
# 86621                        Departamento - P.Avellaneda
# 86622                        Departamento - P.Avellaneda
# 86623                        Departamento - P.Avellaneda
# 86624                        Departamento - P.Avellaneda
# 86625                        Departamento - P.Avellaneda
# 86626  Unico tres ambientes en suite con terraza de 4...
# 86627                    Duplex 3 amb  - Olivos-Vias/Rio
# 86628                             Departamento - Coghlan
# 86629                     Departamento - Olivos-Vias/Rio
# 86630                           Departamento - Caballito
# 86631         VENTA SEMIPISO CON BAULERA EN BARRIO NORTE
# 86632                                       Casa - Haedo
# 86633                            Departamento - Recoleta
# 86634  Departamento 2 ambientes, LOFT IMPECABLE, segu...
# 86635                             Departamento - Palermo
# 86636                                      Casa - Matheu
# 86637                        Departamento - Barrio Norte
# 86638                             Departamento - Coghlan
# 86639         VENTA DEPARTAMENTO 2 AMBIENTES EN BELGRANO
#
#                                          image_thumbnail Cant_EspaciosVerdes  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2                                                    NaN                 NaN
# 3                                                    NaN                 NaN
# 4                                                    NaN                 NaN
# 5                                                    NaN                 NaN
# 6                                                    NaN                 NaN
# 7                                                    NaN                 NaN
# 8                                                    NaN                 NaN
# 9                                                    NaN                 NaN
# 10                                                   NaN                 NaN
# 11                                                   NaN                 NaN
# 12                                                   NaN                 NaN
# 13                                                   NaN                 NaN
# 14                                                   NaN                 NaN
# 15                                                   NaN                 NaN
# 16                                                   NaN                 NaN
# 17                                                   NaN                 NaN
# 18                                                   NaN                 NaN
# 19                                                   NaN                 NaN
# 20                                                   NaN                 NaN
# 21                                                   NaN                 NaN
# 22                                                   NaN                 NaN
# 23                                                   NaN                 NaN
# 24                                                   NaN                 NaN
# 25                                                   NaN                 NaN
# 26                                                   NaN                 NaN
# 27                                                   NaN                 NaN
# 28                                                   NaN                 NaN
# 29                                                   NaN                 NaN
# ...                                                  ...                 ...
# 86610  https://thumbs4.properati.com/0/zeLNBuyylOJL7z...                 2.0
# 86611  https://thumbs4.properati.com/1/bjms0KnaAnlNoQ...                 8.0
# 86612  https://thumbs4.properati.com/2/PCc3WuQDjpNZc4...                 0.0
# 86613  https://thumbs4.properati.com/9/YAe_-2gRVykADP...                 3.0
# 86614  https://thumbs4.properati.com/8/mNEsnQWqB7joBF...                 1.0
# 86615  https://thumbs4.properati.com/3/g4Jwgp_pngLLc6...                 2.0
# 86616  https://thumbs4.properati.com/7/4fPCbuywv2CJmA...                 5.0
# 86617  https://thumbs4.properati.com/6/bvFwfyxtwU_GdI...                 3.0
# 86618  https://thumbs4.properati.com/7/1VQwW0kz8vxAu9...                 2.0
# 86619  https://thumbs4.properati.com/2/lD6Jqa3cZOM5ST...                 8.0
# 86620  https://thumbs4.properati.com/4/8DPBwgQ2Jghc6i...                 1.0
# 86621  https://thumbs4.properati.com/3/OYoHMYuDXL6teS...                 1.0
# 86622  https://thumbs4.properati.com/6/m20phdKst-j_nm...                 1.0
# 86623  https://thumbs4.properati.com/6/ZGwiC9UDVGQIsK...                 1.0
# 86624  https://thumbs4.properati.com/2/U7dlMXUOK0sW74...                 1.0
# 86625  https://thumbs4.properati.com/7/rqMOq2rV238t3Q...                 1.0
# 86626  https://thumbs4.properati.com/6/kxfDYpB1ThD-7i...                 2.0
# 86627  https://thumbs4.properati.com/6/LCcBTRFB9NsjvI...                 2.0
# 86628  https://thumbs4.properati.com/1/nWCYZz5lXv7xd9...                 0.0
# 86629  https://thumbs4.properati.com/5/fzBYPpujPESqmO...                 2.0
# 86630  https://thumbs4.properati.com/6/c4KKVceppth6fJ...                 2.0
# 86631  https://thumbs4.properati.com/1/OxCaZmF6mOoLAF...                13.0
# 86632  https://thumbs4.properati.com/8/OzHne4IbOO_hY7...                 0.0
# 86633  https://thumbs4.properati.com/9/AuVygbiMwXWZEl...                 8.0
# 86634  https://thumbs4.properati.com/0/1WKMf66sLf2QqU...                 8.0
# 86635  https://thumbs4.properati.com/9/T4zOd6wKl5rKPo...                 2.0
# 86636  https://thumbs4.properati.com/2/fjwjasRjm5fF1S...                 0.0
# 86637  https://thumbs4.properati.com/2/i044zFD6MObjXI...                13.0
# 86638  https://thumbs4.properati.com/2/Kcm1LLPAPoFvWN...                 2.0
# 86639  https://thumbs4.properati.com/7/0v8-eKRb7rn0VR...                 1.0
#
#        Cant_LugaresTuristicos  ambientes  banios
# 0                         NaN        NaN     NaN
# 1                         NaN        NaN     NaN
# 2                         NaN        NaN     NaN
# 3                         NaN        NaN     NaN
# 4                         NaN        NaN     NaN
# 5                         NaN        NaN     NaN
# 6                         NaN        NaN     NaN
# 7                         NaN        NaN     NaN
# 8                         NaN        NaN     NaN
# 9                         NaN        NaN     NaN
# 10                        NaN        NaN     NaN
# 11                        NaN        NaN     NaN
# 12                        NaN        NaN     NaN
# 13                        NaN        NaN     NaN
# 14                        NaN        NaN     NaN
# 15                        NaN        NaN     NaN
# 16                        NaN        NaN     NaN
# 17                        NaN        NaN     NaN
# 18                        NaN        NaN     NaN
# 19                        NaN        NaN     NaN
# 20                        NaN        NaN     NaN
# 21                        NaN        NaN     NaN
# 22                        NaN        NaN     NaN
# 23                        NaN        NaN     NaN
# 24                        NaN        NaN     NaN
# 25                        NaN        NaN     NaN
# 26                        NaN        NaN     NaN
# 27                        NaN        NaN     NaN
# 28                        NaN        NaN     NaN
# 29                        NaN        NaN     NaN
# ...                       ...        ...     ...
# 86610                     4.0        NaN     2.0
# 86611                    13.0        3.0     2.0
# 86612                     0.0        NaN     NaN
# 86613                     7.0        1.0     NaN
# 86614                     4.0        NaN     NaN
# 86615                    10.0        NaN     NaN
# 86616                    13.0        2.0     NaN
# 86617                     8.0        NaN     1.0
# 86618                     2.0        3.0     NaN
# 86619                    13.0        3.0     NaN
# 86620                     4.0        3.0     NaN
# 86621                     4.0        3.0     NaN
# 86622                     4.0        3.0     NaN
# 86623                     4.0        3.0     NaN
# 86624                     4.0        3.0     NaN
# 86625                     4.0        3.0     NaN
# 86626                     5.0        NaN     NaN
# 86627                     2.0        3.0     NaN
# 86628                     4.0        3.0     NaN
# 86629                     2.0        4.0     NaN
# 86630                    10.0        4.0     NaN
# 86631                    13.0        NaN     NaN
# 86632                     0.0        4.0     1.0
# 86633                    11.0        1.0     NaN
# 86634                    11.0        2.0     NaN
# 86635                     8.0        2.0     1.0
# 86636                     5.0        NaN     1.0
# 86637                    12.0        2.0     NaN
# 86638                     5.0        3.0     NaN
# 86639                     6.0        2.0     NaN
#
# [86640 rows x 35 columns]

# %%
#completo las superficies totales con las cubiertas
propTOT['surface_total_in_m2'] = propTOT.apply(lambda row: row[12] if(np.all(pd.isnull(row[11]))) else row[11], axis=1)
#cortamos por precios
propTOT = propTOT[(propTOT['price_usd_per_m2']<8000)]

# %% [markdown]
# ## Division del set de Entrenamiento

# %%
#se formatea lat y lon
p = propTOT[['property_type','place_name','surface_total_in_m2',\
          'price_usd_per_m2','latlon','Cant_ColeYUniv','Cant_LocalesGastronomicos',
         'Cant_ParadasTransporte', 'price_aprox_usd']]
p.dropna(inplace = True)

p['lat'] = p.apply(lambda row: row[4][0], axis=1)

p['lon'] = p.apply(lambda row: row[4][1], axis=1)

p = p[['property_type','place_name','surface_total_in_m2',\
          'price_usd_per_m2','lat','lon','Cant_ColeYUniv','Cant_LocalesGastronomicos',
         'Cant_ParadasTransporte', 'price_aprox_usd']]
# Out:
# /home/facundo/.local/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/facundo/.local/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/facundo/.local/lib/python2.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Se le asigna un valor numerico al tipo de propiedad

# %%
def asignarPT( p ):
    if p == 'apartment':
        return 3
    if p == 'house':
        return 2.25
    if p == 'store':
        return 6.5
    return 2.5

# %%
p['property_type'] = p.apply(lambda x: asignarPT(x[0]), axis = 1)

# %% [markdown]
# ### Se le asigna un valor a los barrios segun el analisis de grupos hecho en el tp1

# %%
def asignarPV(name, dic):
    return dic[name]

# %%
hoodGroups = p[["place_name", "price_usd_per_m2"]]
hoodGroups = hoodGroups.groupby("place_name").agg([np.mean]).reset_index()
hoodGroups = hoodGroups.sort_values(by=("price_usd_per_m2", "mean"), ascending=False)

# %%
HGdics = {}
precio_ant = 0
val_ant = 0
for row in hoodGroups.iterrows():
    name = row[1][0]
    price = row[1][1]
    val = val_ant + (precio_ant/price)
    HGdics[name] = val
    precio_ant = price
    val_ant = val

# %%
p["place_value"] = p.apply(lambda x: asignarPV(x[1], HGdics), axis=1)

# %%
pEnt = p[['property_type','surface_total_in_m2',\
          'lat','lon','Cant_LocalesGastronomicos',
         'Cant_ParadasTransporte', 'place_value', 'price_aprox_usd']]

# %%
pEnt.dropna(inplace=True)
# Out:
# /home/facundo/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Se carga el set de Prueba

# %%
proper = pickle.load(open("../../datos/propiedadesPruebaConColTransGas.p", "rb"))

#se formatea lat y lon
p = proper[['property_type','place_name','surface_total_in_m2','surface_covered_in_m2',\
          'latlon','Cant_ColeYUniv','Cant_LocalesGastronomicos',
         'Cant_ParadasTransporte', 'price_aprox_usd']]

p['lat'] = p.apply(lambda row: row[4][0] if(np.all(pd.notnull(row[5]))) else row[5], axis=1)

p['lon'] = p.apply(lambda row: row[4][1] if(np.all(pd.notnull(row[5]))) else row[5], axis=1)

p = p[['property_type','place_name','surface_total_in_m2','surface_covered_in_m2',\
          'lat','lon','Cant_ColeYUniv','Cant_LocalesGastronomicos',
         'Cant_ParadasTransporte', 'price_aprox_usd']]

p['property_type'] = p.apply(lambda x: asignarPT(x[0]), axis = 1)

def asignarPVsegunEnt(name):
    if(HGdics.has_key(name)):
        return HGdics[name]
    return np.nan

#hay que armar los hoodGropus segun los resultados del set de Entrenamiento
p["place_value"] = p.apply(lambda x: asignarPVsegunEnt(x[1]), axis=1)

#completo las superficies totales con las cubiertas
p['surface_total_in_m2'] = p.apply(lambda row: row[3] if(np.all(pd.isnull(row[2]))) else row[2], axis=1)

pPru = p[['property_type','surface_total_in_m2',\
        'lat','lon','Cant_ColeYUniv','Cant_LocalesGastronomicos',
         'Cant_ParadasTransporte', 'place_value', 'price_aprox_usd']]
# Out:
# /home/facundo/.local/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/facundo/.local/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
pEnt.describe()

# %%
pPru.describe()

# %%
def reemplazarGast(x):
    if(x==0):
        return 0
    return (math.log10(x))

# %%
pEnt['Cant_LocalesGastronomicos'] = pEnt.apply(lambda row: reemplazarGast(row[4]), axis=1)
pEnt
# Out:
#        property_type  surface_total_in_m2        lat        lon  \
# 2               2.50                100.0 -34.564522 -58.486977
# 3               2.50                115.0 -34.583011 -58.595992
# 4               2.50                 90.0 -34.580038 -58.592722
# 5               2.50                 70.0 -34.575744 -58.604072
# 6               2.50                 94.0 -34.562700 -58.458290
# 7               2.50                713.0 -34.899413 -58.488304
# 9               2.50                155.0 -34.562824 -58.443615
# 13                      1.602060                    37.0   173.481947
# 14                      0.000000                     0.0   334.984512
# 15                      1.462398                     2.0   434.681126
# 16                      1.462398                     2.0   434.681126
# 18                      2.296665                    13.0    69.100614
# 19                      0.698970                     4.0   359.098828
# 21                      2.296665                    27.0     5.573867
# 23                      0.903090                    21.0   284.756184
# 24                      0.778151                     0.0   283.756064
# 25                      0.301030                     0.0   408.377996
# 27                      0.000000                     0.0   446.864284
# 28                      0.000000                     0.0   408.377996
# 29                      0.000000                     0.0   283.756064
# 30                      0.845098                     8.0   450.905728
# 31                      0.301030                     0.0   434.681126
# 32                      1.986772                    14.0    25.870028
# 33                      1.041393                     9.0   283.756064
# 34                      0.000000                     4.0   475.361584
# 35                      0.000000                     2.0   446.864284
# 36                      1.556303                     9.0   283.756064
# 37                      0.301030                    12.0   364.126848
# ...                          ...                     ...          ...
# 86610                   1.929419                    15.0    10.643192
# 86611                   2.301030                    24.0    10.643192
# 86612                   1.204120                    23.0   123.327904
# 86613                   1.826075                    14.0    26.877991
# 86614                   1.785330                    15.0   146.400264
# 86615                   2.301030                    26.0    29.901094
# 86616                   2.298853                    26.0     5.573867
# 86617                   1.763428                    11.0   146.400264
# 86618                   1.414973                    16.0    20.831729
# 86619                   2.301030                    24.0    10.643192
# 86620                   1.785330                    15.0   146.400264
# 86621                   1.785330                    15.0   146.400264
# 86622                   1.785330                    15.0   146.400264
# 86623                   1.785330                    15.0   146.400264
# 86624                   1.785330                    15.0   146.400264
# 86625                   1.785330                    15.0   146.400264
# 86626                   2.193125                    14.0    11.658309
# 86627                   1.414973                    16.0    20.831729
# 86628                   1.838849                    25.0    25.870028
# 86629                   1.414973                    16.0    20.831729
# 86630                   2.301030                    26.0    29.901094
# 86631                   1.903090                    15.0    13.685335
# 86632                   0.000000                     0.0   286.758743
# 86633                   2.296665                    27.0     5.573867
# 86634                   2.296665                    27.0     5.573867
# 86635                   1.919078                    11.0     6.592418
# 86636                   1.505150                     0.0   371.191492
# 86637                   2.000000                    17.0    13.685335
# 86638                   1.748188                    23.0    26.877991
# 86639                   1.913814                     9.0    10.643192
#
#        price_aprox_usd
# 2             12554.74
# 3             13000.00
# 4             13000.00
# 5             13000.00
# 6             14266.73
# 7             15595.21
# 9             16887.74
# 10            17518.25
# 12            20963.50
# 13            21000.00
# 14            21082.42
# 15            22250.74
# 16            22250.74
# 18            25000.00
# 19            25109.49
# 21            28302.43
# 23            29000.00
# 24            29197.08
# 25            29197.08
# 27            29197.08
# 28            29197.08
# 29            29197.08
# 30            29197.08
# 31            29197.08
# 32            30000.00
# 33            30000.00
# 34            30000.00
# 35            30000.00
# 36            30000.00
# 37            30000.00
# ...                ...
# 86610        410000.00
# 86611        870000.00
# 86612        498000.00
# 86613        131500.00
# 86614        129000.00
# 86615        205000.00
# 86616        220000.00
# 86617         60000.00
# 86618        452100.00
# 86619        490000.00
# 86620        144000.00
# 86621        141000.00
# 86622        138800.00
# 86623        133000.00
# 86624        135000.00
# 86625        137000.00
# 86626        380000.00
# 86627        548200.00
# 86628        219000.00
# 86629        652200.00
# 86630        330000.00
# 86631        245000.00
# 86632        120000.00
# 86633        142000.00
# 86634        215000.00
# 86635        145000.00
# 86636        118000.00
# 86637        155000.00
# 86638        219000.00
# 86639        108000.00
#
# [78368 rows x 8 columns]

# %%
pPru['Cant_LocalesGastronomicos'] = pPru.apply(lambda row: reemplazarGast(row[5]), axis=1)
pPru
# Out:
# /home/facundo/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 11      117.300270         18218.04
# 12      117.300270         20963.50
# 13      173.481947         21000.00
# 14      334.984512         21082.42
# 15      434.681126         22250.74
# 16      434.681126         22250.74
# 17      459.035500         23357.66
# 18       69.100614         25000.00
# 19      359.098828         25109.49
# 20      423.506366         28029.20
# 21        5.573867         28302.43
# 22      421.500802         29000.00
# 23      284.756184         29000.00
# 24      283.756064         29197.08
# 25      408.377996         29197.08
# 26      290.769015         29197.08
# 27      446.864284         29197.08
# 28      408.377996         29197.08
# 29      283.756064         29197.08
# ...            ...              ...
# 14136    51.013230              NaN
# 14137    11.658309              NaN
# 14138    68.099305              NaN
# 14139    70.105952              NaN
# 14140    16.702668              NaN
# 14141    23.861793              NaN
# 14142    11.658309              NaN
# 14143     6.592418              NaN
# 14144    92.191591              NaN
# 14145    23.861793              NaN
# 14146    53.026444              NaN
# 14147   234.600520              NaN
# 14148    26.877991              NaN
# 14149    89.180914              NaN
# 14150    88.176145              NaN
# 14151    65.084555              NaN
# 14152    80.146601              NaN
# 14153    59.036605              NaN
# 14154    10.643192              NaN
# 14155   398.323048              NaN
# 14156   202.545970              NaN
# 14157   172.481669              NaN
# 14158   128.342563              NaN
# 14159     7.613035              NaN
# 14160     7.613035              NaN
# 14161     0.000000              NaN
# 14162   155.428996              NaN
# 14163   117.300270              NaN
# 14164    10.643192              NaN
# 14165   372.201605              NaN
#
# [14166 rows x 9 columns]

# %%
def reemplazarParadas(x):
    return (x*10)/59

# %%
pEnt['Cant_ParadasTransporte'] = pEnt.apply(lambda row: reemplazarParadas(row[5]), axis=1)

# %%
pPru['Cant_ParadasTransporte'] = pPru.apply(lambda row: reemplazarParadas(row[6]), axis=1)

# %%
#split del dataset para entrenamiento y pruebas, 80% y 20% respectivamente
Xtrn, Xtest, Ytrn, Ytest = train_test_split(pEnt[['property_type','surface_total_in_m2',
        'place_value','Cant_LocalesGastronomicos']],pEnt[['price_aprox_usd']],test_size=0.0)

# %%
#definir el modelo a probar
model = GradientBoostingRegressor(loss = 'ls', n_estimators = 5000, max_depth = 5, learning_rate = 0.241)

#fit model on training dataset
model.fit(Xtrn, Ytrn['price_aprox_usd'])
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.241, loss='ls', max_depth=5,
#              max_features=None, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=5000,
#              presort='auto', random_state=None, subsample=1.0, verbose=0,
#              warm_start=False)

# %%
from sklearn.preprocessing import Imputer
#hay que llenar el resto de los valores nan

# Create our imputer to replace missing values with the mean e.g.
imp = Imputer(missing_values=np.nan, strategy='most_frequent', axis=1)
imp = imp.fit(Xtrn)

pPru_imp = imp.transform(pPru[['property_type','surface_total_in_m2',
        'place_value','Cant_LocalesGastronomicos']])

# %%
pPru['price_usd'] = model.predict(pPru_imp)
# Out:
# /home/facundo/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
result = pd.DataFrame()

# %%
result["id"] = proper["id"]

# %%
result["price_usd"] = pPru['price_usd']

# %%
result.head()
# Out:
#         id      price_usd
# 0  2316505  189067.730047
# 1  2320880  219272.458623
# 2  2321742  165090.185999
# 3  2276796   85201.945039
# 4  2330364   60317.780760

# %%
result.to_csv(index=False, path_or_buf="resultsGB3PhiAlpha.csv")

# %%
model.feature_importances_
# Out:
# array([ 0.06254951,  0.40820262,  0.27175514,  0.25749273])
